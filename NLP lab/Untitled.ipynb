# %%
print "a"
# Out:
#   Cell In[1], line 1
#     print "a"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print("a")
# Out:
# a

# %%
import numpy as np

# %%
arr = np.a
